# %%
import spotipy
import json
import webbrowser
import time
import pandas

# %%
import urllib.request
import spotipy.util as util

# %%
from osc4py3.as_eventloop import *
from osc4py3 import oscbuildparse

# %%
from pythonosc import osc_message_builder
from pythonosc import udp_client

# %%
#from pyagify.agify import AgifyClient

# %%
# Start the system.
#osc_startup()

# Make client channels to send packets.
#osc_udp_client("10.106.33.118", 7771, "processing")

# %%
client = udp_client.UDPClient("10.106.33.118", 7771)

# %%
titleName = str(input("Type the Title:"))
#titleName = ("love")

#client = AgifyClient()
#gender = client.get_age(str(input("Predict your age by the name:")))
#print(gender)

url = "https://api.agify.io/?name=" + titleName
# Out:
# Type the Title: yong

# %%
request = urllib.request.Request(url)

# %%
response = urllib.request.urlopen(request)

# %%
response.status
print(response)
# Out:
# <http.client.HTTPResponse object at 0x000001F3393DFDF0>

# %%
name = json.loads(response.read())

# %%
Age = name["age"]
print("Predicted age:" + str(Age))
# Out:
# Predicted age:56

# %%
age_wriiten = ""
if Age >= 69 and Age <= 95:
    age_written = "1955"
elif Age >= 43 and Age <= 68:
    age_written = "1975"
elif Age >= 25 and Age <= 42:
    age_written = "1995"

age_written
# Out:
# '1975'

# %%
#Open file with keys 
credentials = "spotifyOSC.json"
with open(credentials, "r") as keys:
    api_tokens = json.load(keys)

# %%
api_tokens
# Out:
# {'username': '314wf45dozkavng65w4lfcwguz5e',
#  'client_id': '5a4f585949dc4f4d8971ad131dacec18',
#  'client_secret': 'e9a58c2d7c314b979c3253c238f0c4f3',
#  'redirect': 'http://google.com/'}

# %%
client_id = api_tokens["client_id"]
client_secret = api_tokens["client_secret"]
redirectURI = api_tokens["redirect"]
username = api_tokens["username"]

# %%
username
# Out:
# '314wf45dozkavng65w4lfcwguz5e'

# %%
scope = 'user-read-private user-read-playback-state user-modify-playback-state playlist-modify-public'
token = util.prompt_for_user_token(username, scope, client_id=client_id,
                           client_secret=client_secret,
                           redirect_uri=redirectURI)

# %%
token
# Out:
# 'BQBSyyPMHb4gpAFJOCrXaDUAveSu4a4iKT6O-uxBVqt3qTEuNJr_tJLVp2TUaAggAbopjUUH7io3YOfjeAf-1wdSrHz-8O6oAYMFVAgb91LNXOjlMKi2Z85PGcwYe3EmY3bdEzkLoeerywDwbtYgs71YrChZ99zAvAfdnBEqtj48Xt0-mtB57edduoaX-Gm6smrKqYNcOkrvpQHK0-9x7lIWUxkaiVriQu93z0-WpGbw-ZKuqCN8hV8'

# %%
# Create Spotify Object
# Setting the authorization with the final key, ie the token
sp = spotipy.Spotify(auth=token)

# %%
devices = sp.devices()
print(devices)
deviceID = devices['devices'][0]['id']
# Out:
# {'devices': [{'id': '13f1d792ba5f47c52676d5a21d324140c98c2f02', 'is_active': False, 'is_private_session': False, 'is_restricted': False, 'name': 'Web Player (Chrome)', 'supports_volume': True, 'type': 'Computer', 'volume_percent': 100}, {'id': '4c59af4ae89639774d913245813fc9b9c8477fbc', 'is_active': False, 'is_private_session': False, 'is_restricted': False, 'name': 'LAPTOP-8SPQ0OGK', 'supports_volume': True, 'type': 'Computer', 'volume_percent': 100}, {'id': '23f9bf43a95deeb9f8fec706cff8b890b80208ee', 'is_active': False, 'is_private_session': False, 'is_restricted': False, 'name': 'Web Player (Chrome)', 'supports_volume': True, 'type': 'Computer', 'volume_percent': 100}, {'id': '13f5569214387eb460c3b58453ee051878b1736c', 'is_active': False, 'is_private_session': False, 'is_restricted': False, 'name': 'Web Player (Chrome)', 'supports_volume': True, 'type': 'Computer', 'volume_percent': 100}, {'id': '145fb22e68f6e5b77ff18ac3c9c2419ef31a11af', 'is_active': False, 'is_private_session': False, 'is_restricted': False, 'name': 'Web Player (Chrome)', 'supports_volume': True, 'type': 'Computer', 'volume_percent': 100}]}

# %%
track_results = sp.search(q="year:" + age_written, type='track', limit=50)

# %%
tracks = track_results['tracks']['items']

# %%
track_selection_list = []
track_selection_id = []

for song in tracks:
     track_selection_id.append(song['id'])
     track_selection_list.append(song['uri'])
     
#print(track_selection_id)

# %%
features = sp.audio_features(track_selection_id)
features
# Out:
# [{'danceability': 0.749,
#   'energy': 0.748,
#   'key': 2,
#   'loudness': -7.011,
#   'mode': 1,
#   'speechiness': 0.0323,
#   'acousticness': 0.295,
#   'instrumentalness': 0.000443,
#   'liveness': 0.469,
#   'valence': 0.827,
#   'tempo': 137.547,
#   'type': 'audio_features',
#   'id': '2TxCwUlqaOH3TIyJqGgR91',
#   'uri': 'spotify:track:2TxCwUlqaOH3TIyJqGgR91',
#   'track_href': 'https://api.spotify.com/v1/tracks/2TxCwUlqaOH3TIyJqGgR91',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2TxCwUlqaOH3TIyJqGgR91',
#   'duration_ms': 213267,
#   'time_signature': 4},
#  {'danceability': 0.812,
#   'energy': 0.644,
#   'key': 0,
#   'loudness': -10.761,
#   'mode': 1,
#   'speechiness': 0.0493,
#   'acousticness': 0.0877,
#   'instrumentalness': 0.785,
#   'liveness': 0.0563,
#   'valence': 0.989,
#   'tempo': 140.075,
#   'type': 'audio_features',
#   'id': '7Bz8yww6UMbTgTVLG6zbI4',
#   'uri': 'spotify:track:7Bz8yww6UMbTgTVLG6zbI4',
#   'track_href': 'https://api.spotify.com/v1/tracks/7Bz8yww6UMbTgTVLG6zbI4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7Bz8yww6UMbTgTVLG6zbI4',
#   'duration_ms': 190827,
#   'time_signature': 4},
#  {'danceability': 0.362,
#   'energy': 0.336,
#   'key': 0,
#   'loudness': -11.237,
#   'mode': 1,
#   'speechiness': 0.039,
#   'acousticness': 0.379,
#   'instrumentalness': 0.0411,
#   'liveness': 0.472,
#   'valence': 0.934,
#   'tempo': 118.784,
#   'type': 'audio_features',
#   'id': '3cbEoHzeiebNIZLpaeC0jB',
#   'uri': 'spotify:track:3cbEoHzeiebNIZLpaeC0jB',
#   'track_href': 'https://api.spotify.com/v1/tracks/3cbEoHzeiebNIZLpaeC0jB',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3cbEoHzeiebNIZLpaeC0jB',
#   'duration_ms': 171227,
#   'time_signature': 4},
#  {'danceability': 0.404,
#   'energy': 0.523,
#   'key': 4,
#   'loudness': -15.7,
#   'mode': 1,
#   'speechiness': 0.0575,
#   'acousticness': 0.685,
#   'instrumentalness': 0.000498,
#   'liveness': 0.282,
#   'valence': 0.164,
#   'tempo': 133.738,
#   'type': 'audio_features',
#   'id': '5HQEmiV2lKnSO6qa2fsR7x',
#   'uri': 'spotify:track:5HQEmiV2lKnSO6qa2fsR7x',
#   'track_href': 'https://api.spotify.com/v1/tracks/5HQEmiV2lKnSO6qa2fsR7x',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5HQEmiV2lKnSO6qa2fsR7x',
#   'duration_ms': 366640,
#   'time_signature': 4},
#  {'danceability': 0.414,
#   'energy': 0.161,
#   'key': 7,
#   'loudness': -22.32,
#   'mode': 0,
#   'speechiness': 0.0318,
#   'acousticness': 0.883,
#   'instrumentalness': 0.000223,
#   'liveness': 0.117,
#   'valence': 0.423,
#   'tempo': 159.375,
#   'type': 'audio_features',
#   'id': '5ihS6UUlyQAfmp48eSkxuQ',
#   'uri': 'spotify:track:5ihS6UUlyQAfmp48eSkxuQ',
#   'track_href': 'https://api.spotify.com/v1/tracks/5ihS6UUlyQAfmp48eSkxuQ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5ihS6UUlyQAfmp48eSkxuQ',
#   'duration_ms': 199493,
#   'time_signature': 4},
#  {'danceability': 0.729,
#   'energy': 0.844,
#   'key': 5,
#   'loudness': -8.824,
#   'mode': 1,
#   'speechiness': 0.0344,
#   'acousticness': 0.149,
#   'instrumentalness': 2.87e-06,
#   'liveness': 0.0604,
#   'valence': 0.777,
#   'tempo': 131.459,
#   'type': 'audio_features',
#   'id': '7HW5WIw7ZgZORCzUxv5gW5',
#   'uri': 'spotify:track:7HW5WIw7ZgZORCzUxv5gW5',
#   'track_href': 'https://api.spotify.com/v1/tracks/7HW5WIw7ZgZORCzUxv5gW5',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7HW5WIw7ZgZORCzUxv5gW5',
#   'duration_ms': 275440,
#   'time_signature': 4},
#  {'danceability': 0.764,
#   'energy': 0.628,
#   'key': 0,
#   'loudness': -10.961,
#   'mode': 1,
#   'speechiness': 0.048,
#   'acousticness': 0.336,
#   'instrumentalness': 0,
#   'liveness': 0.0977,
#   'valence': 0.823,
#   'tempo': 109.008,
#   'type': 'audio_features',
#   'id': '75Nlnd9AJ4CYrLXgWGsuTF',
#   'uri': 'spotify:track:75Nlnd9AJ4CYrLXgWGsuTF',
#   'track_href': 'https://api.spotify.com/v1/tracks/75Nlnd9AJ4CYrLXgWGsuTF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/75Nlnd9AJ4CYrLXgWGsuTF',
#   'duration_ms': 216387,
#   'time_signature': 4},
#  {'danceability': 0.427,
#   'energy': 0.459,
#   'key': 9,
#   'loudness': -12.442,
#   'mode': 0,
#   'speechiness': 0.0332,
#   'acousticness': 0.116,
#   'instrumentalness': 0.000103,
#   'liveness': 0.132,
#   'valence': 0.383,
#   'tempo': 129.878,
#   'type': 'audio_features',
#   'id': '5zH710lFSLtkHbMkslLDjR',
#   'uri': 'spotify:track:5zH710lFSLtkHbMkslLDjR',
#   'track_href': 'https://api.spotify.com/v1/tracks/5zH710lFSLtkHbMkslLDjR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5zH710lFSLtkHbMkslLDjR',
#   'duration_ms': 293440,
#   'time_signature': 4},
#  {'danceability': 0.415,
#   'energy': 0.713,
#   'key': 5,
#   'loudness': -5.55,
#   'mode': 1,
#   'speechiness': 0.0278,
#   'acousticness': 0.251,
#   'instrumentalness': 0.00197,
#   'liveness': 0.289,
#   'valence': 0.579,
#   'tempo': 125.056,
#   'type': 'audio_features',
#   'id': '6yZv0Nl6BXABbXoPVpfF5y',
#   'uri': 'spotify:track:6yZv0Nl6BXABbXoPVpfF5y',
#   'track_href': 'https://api.spotify.com/v1/tracks/6yZv0Nl6BXABbXoPVpfF5y',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6yZv0Nl6BXABbXoPVpfF5y',
#   'duration_ms': 202387,
#   'time_signature': 4},
#  {'danceability': 0.723,
#   'energy': 0.49,
#   'key': 9,
#   'loudness': -14.745,
#   'mode': 0,
#   'speechiness': 0.0296,
#   'acousticness': 0.111,
#   'instrumentalness': 0.0946,
#   'liveness': 0.0923,
#   'valence': 0.795,
#   'tempo': 129.012,
#   'type': 'audio_features',
#   'id': '05oETzWbd4SI33qK2gbJfR',
#   'uri': 'spotify:track:05oETzWbd4SI33qK2gbJfR',
#   'track_href': 'https://api.spotify.com/v1/tracks/05oETzWbd4SI33qK2gbJfR',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/05oETzWbd4SI33qK2gbJfR',
#   'duration_ms': 252773,
#   'time_signature': 4},
#  {'danceability': 0.644,
#   'energy': 0.633,
#   'key': 0,
#   'loudness': -8.006,
#   'mode': 1,
#   'speechiness': 0.0261,
#   'acousticness': 0.102,
#   'instrumentalness': 6.82e-05,
#   'liveness': 0.227,
#   'valence': 0.647,
#   'tempo': 115.193,
#   'type': 'audio_features',
#   'id': '0VwTeYNjcl30DyQlt3GPe0',
#   'uri': 'spotify:track:0VwTeYNjcl30DyQlt3GPe0',
#   'track_href': 'https://api.spotify.com/v1/tracks/0VwTeYNjcl30DyQlt3GPe0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VwTeYNjcl30DyQlt3GPe0',
#   'duration_ms': 194453,
#   'time_signature': 4},
#  {'danceability': 0.27,
#   'energy': 0.214,
#   'key': 7,
#   'loudness': -15.779,
#   'mode': 0,
#   'speechiness': 0.029,
#   'acousticness': 0.738,
#   'instrumentalness': 0.661,
#   'liveness': 0.117,
#   'valence': 0.0445,
#   'tempo': 135.869,
#   'type': 'audio_features',
#   'id': '32dnKMni3I3gwUbWp4mi45',
#   'uri': 'spotify:track:32dnKMni3I3gwUbWp4mi45',
#   'track_href': 'https://api.spotify.com/v1/tracks/32dnKMni3I3gwUbWp4mi45',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/32dnKMni3I3gwUbWp4mi45',
#   'duration_ms': 810293,
#   'time_signature': 3},
#  {'danceability': 0.655,
#   'energy': 0.675,
#   'key': 1,
#   'loudness': -9.352,
#   'mode': 1,
#   'speechiness': 0.0599,
#   'acousticness': 0.272,
#   'instrumentalness': 0.0236,
#   'liveness': 0.727,
#   'valence': 0.587,
#   'tempo': 77.589,
#   'type': 'audio_features',
#   'id': '423hwXFgoN8RYmqLoLuVvY',
#   'uri': 'spotify:track:423hwXFgoN8RYmqLoLuVvY',
#   'track_href': 'https://api.spotify.com/v1/tracks/423hwXFgoN8RYmqLoLuVvY',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/423hwXFgoN8RYmqLoLuVvY',
#   'duration_ms': 427800,
#   'time_signature': 4},
#  {'danceability': 0.414,
#   'energy': 0.404,
#   'key': 0,
#   'loudness': -9.928,
#   'mode': 0,
#   'speechiness': 0.0499,
#   'acousticness': 0.271,
#   'instrumentalness': 0,
#   'liveness': 0.3,
#   'valence': 0.224,
#   'tempo': 71.105,
#   'type': 'audio_features',
#   'id': '4u7EnebtmKWzUH433cf5Qv',
#   'uri': 'spotify:track:4u7EnebtmKWzUH433cf5Qv',
#   'track_href': 'https://api.spotify.com/v1/tracks/4u7EnebtmKWzUH433cf5Qv',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4u7EnebtmKWzUH433cf5Qv',
#   'duration_ms': 354320,
#   'time_signature': 4},
#  {'danceability': 0.483,
#   'energy': 0.615,
#   'key': 2,
#   'loudness': -8.538,
#   'mode': 1,
#   'speechiness': 0.0497,
#   'acousticness': 0.452,
#   'instrumentalness': 0.000414,
#   'liveness': 0.0512,
#   'valence': 0.594,
#   'tempo': 80.576,
#   'type': 'audio_features',
#   'id': '6Vjk8MNXpQpi0F4BefdTyq',
#   'uri': 'spotify:track:6Vjk8MNXpQpi0F4BefdTyq',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Vjk8MNXpQpi0F4BefdTyq',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Vjk8MNXpQpi0F4BefdTyq',
#   'duration_ms': 517125,
#   'time_signature': 3},
#  {'danceability': 0.664,
#   'energy': 0.547,
#   'key': 9,
#   'loudness': -11.594,
#   'mode': 1,
#   'speechiness': 0.0281,
#   'acousticness': 0.139,
#   'instrumentalness': 1.79e-06,
#   'liveness': 0.239,
#   'valence': 0.964,
#   'tempo': 132.943,
#   'type': 'audio_features',
#   'id': '74jZhGv0fdLaf9q8AZZ15k',
#   'uri': 'spotify:track:74jZhGv0fdLaf9q8AZZ15k',
#   'track_href': 'https://api.spotify.com/v1/tracks/74jZhGv0fdLaf9q8AZZ15k',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/74jZhGv0fdLaf9q8AZZ15k',
#   'duration_ms': 172733,
#   'time_signature': 4},
#  {'danceability': 0.51,
#   'energy': 0.76,
#   'key': 0,
#   'loudness': -6.995,
#   'mode': 1,
#   'speechiness': 0.0411,
#   'acousticness': 0.148,
#   'instrumentalness': 0.0116,
#   'liveness': 0.0706,
#   'valence': 0.55,
#   'tempo': 118.829,
#   'type': 'audio_features',
#   'id': '4vhVDkSx9RSb2k6mWFMYNI',
#   'uri': 'spotify:track:4vhVDkSx9RSb2k6mWFMYNI',
#   'track_href': 'https://api.spotify.com/v1/tracks/4vhVDkSx9RSb2k6mWFMYNI',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4vhVDkSx9RSb2k6mWFMYNI',
#   'duration_ms': 170787,
#   'time_signature': 4},
#  {'danceability': 0.369,
#   'energy': 0.758,
#   'key': 5,
#   'loudness': -5.871,
#   'mode': 1,
#   'speechiness': 0.0364,
#   'acousticness': 0.623,
#   'instrumentalness': 1.78e-05,
#   'liveness': 0.531,
#   'valence': 0.663,
#   'tempo': 140.71,
#   'type': 'audio_features',
#   'id': '56lhDZNQ5J47aog6mGKeGk',
#   'uri': 'spotify:track:56lhDZNQ5J47aog6mGKeGk',
#   'track_href': 'https://api.spotify.com/v1/tracks/56lhDZNQ5J47aog6mGKeGk',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56lhDZNQ5J47aog6mGKeGk',
#   'duration_ms': 288720,
#   'time_signature': 4},
#  {'danceability': 0.677,
#   'energy': 0.619,
#   'key': 9,
#   'loudness': -7.446,
#   'mode': 0,
#   'speechiness': 0.0334,
#   'acousticness': 0.457,
#   'instrumentalness': 0.000149,
#   'liveness': 0.221,
#   'valence': 0.74,
#   'tempo': 119.624,
#   'type': 'audio_features',
#   'id': '777NOXupZkFdg8zlPMoVqc',
#   'uri': 'spotify:track:777NOXupZkFdg8zlPMoVqc',
#   'track_href': 'https://api.spotify.com/v1/tracks/777NOXupZkFdg8zlPMoVqc',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/777NOXupZkFdg8zlPMoVqc',
#   'duration_ms': 269840,
#   'time_signature': 4},
#  {'danceability': 0.737,
#   'energy': 0.495,
#   'key': 1,
#   'loudness': -13.489,
#   'mode': 1,
#   'speechiness': 0.027,
#   'acousticness': 0.0588,
#   'instrumentalness': 9.12e-06,
#   'liveness': 0.0542,
#   'valence': 0.967,
#   'tempo': 104.409,
#   'type': 'audio_features',
#   'id': '1hQFF33xi8ruavZNyovtUN',
#   'uri': 'spotify:track:1hQFF33xi8ruavZNyovtUN',
#   'track_href': 'https://api.spotify.com/v1/tracks/1hQFF33xi8ruavZNyovtUN',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1hQFF33xi8ruavZNyovtUN',
#   'duration_ms': 197147,
#   'time_signature': 4},
#  {'danceability': 0.329,
#   'energy': 0.179,
#   'key': 5,
#   'loudness': -11.589,
#   'mode': 1,
#   'speechiness': 0.0299,
#   'acousticness': 0.933,
#   'instrumentalness': 5.04e-06,
#   'liveness': 0.115,
#   'valence': 0.255,
#   'tempo': 154.175,
#   'type': 'audio_features',
#   'id': '4YJUTdZ0Pgl0ZeNyHYXeLd',
#   'uri': 'spotify:track:4YJUTdZ0Pgl0ZeNyHYXeLd',
#   'track_href': 'https://api.spotify.com/v1/tracks/4YJUTdZ0Pgl0ZeNyHYXeLd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4YJUTdZ0Pgl0ZeNyHYXeLd',
#   'duration_ms': 217387,
#   'time_signature': 4},
#  {'danceability': 0.671,
#   'energy': 0.776,
#   'key': 10,
#   'loudness': -11.414,
#   'mode': 1,
#   'speechiness': 0.0282,
#   'acousticness': 0.137,
#   'instrumentalness': 0.00649,
#   'liveness': 0.394,
#   'valence': 0.92,
#   'tempo': 112.629,
#   'type': 'audio_features',
#   'id': '6zbFTYeqNvZdms60HouEFT',
#   'uri': 'spotify:track:6zbFTYeqNvZdms60HouEFT',
#   'track_href': 'https://api.spotify.com/v1/tracks/6zbFTYeqNvZdms60HouEFT',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6zbFTYeqNvZdms60HouEFT',
#   'duration_ms': 317160,
#   'time_signature': 4},
#  {'danceability': 0.43,
#   'energy': 0.374,
#   'key': 11,
#   'loudness': -9.949,
#   'mode': 1,
#   'speechiness': 0.0292,
#   'acousticness': 0.372,
#   'instrumentalness': 0.379,
#   'liveness': 0.316,
#   'valence': 0.191,
#   'tempo': 128.56,
#   'type': 'audio_features',
#   'id': '6OuRbvP4PgbuzBIapVzmFJ',
#   'uri': 'spotify:track:6OuRbvP4PgbuzBIapVzmFJ',
#   'track_href': 'https://api.spotify.com/v1/tracks/6OuRbvP4PgbuzBIapVzmFJ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6OuRbvP4PgbuzBIapVzmFJ',
#   'duration_ms': 277960,
#   'time_signature': 4},
#  {'danceability': 0.441,
#   'energy': 0.547,
#   'key': 4,
#   'loudness': -12.222,
#   'mode': 1,
#   'speechiness': 0.0337,
#   'acousticness': 0.13,
#   'instrumentalness': 0.000143,
#   'liveness': 0.109,
#   'valence': 0.716,
#   'tempo': 134.753,
#   'type': 'audio_features',
#   'id': '5VSAonaAPhhGn0G7hMYwWK',
#   'uri': 'spotify:track:5VSAonaAPhhGn0G7hMYwWK',
#   'track_href': 'https://api.spotify.com/v1/tracks/5VSAonaAPhhGn0G7hMYwWK',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5VSAonaAPhhGn0G7hMYwWK',
#   'duration_ms': 199573,
#   'time_signature': 4},
#  {'danceability': 0.685,
#   'energy': 0.623,
#   'key': 8,
#   'loudness': -11.146,
#   'mode': 1,
#   'speechiness': 0.042,
#   'acousticness': 0.228,
#   'instrumentalness': 0.00234,
#   'liveness': 0.0295,
#   'valence': 0.896,
#   'tempo': 126.739,
#   'type': 'audio_features',
#   'id': '0PDCewmZCp0P5s00bptcdd',
#   'uri': 'spotify:track:0PDCewmZCp0P5s00bptcdd',
#   'track_href': 'https://api.spotify.com/v1/tracks/0PDCewmZCp0P5s00bptcdd',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0PDCewmZCp0P5s00bptcdd',
#   'duration_ms': 171960,
#   'time_signature': 4},
#  {'danceability': 0.655,
#   'energy': 0.606,
#   'key': 7,
#   'loudness': -10.385,
#   'mode': 1,
#   'speechiness': 0.0285,
#   'acousticness': 0.0603,
#   'instrumentalness': 0.0789,
#   'liveness': 0.0757,
#   'valence': 0.765,
#   'tempo': 110.061,
#   'type': 'audio_features',
#   'id': '608xszaAxVh4m7NcKJiAbF',
#   'uri': 'spotify:track:608xszaAxVh4m7NcKJiAbF',
#   'track_href': 'https://api.spotify.com/v1/tracks/608xszaAxVh4m7NcKJiAbF',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/608xszaAxVh4m7NcKJiAbF',
#   'duration_ms': 291686,
#   'time_signature': 4},
#  {'danceability': 0.815,
#   'energy': 0.372,
#   'key': 7,
#   'loudness': -12.814,
#   'mode': 1,
#   'speechiness': 0.0752,
#   'acousticness': 0.166,
#   'instrumentalness': 0.000116,
#   'liveness': 0.0767,
#   'valence': 0.293,
#   'tempo': 101.684,
#   'type': 'audio_features',
#   'id': '6Qb7gtV6Q4MnUjSbkFcopl',
#   'uri': 'spotify:track:6Qb7gtV6Q4MnUjSbkFcopl',
#   'track_href': 'https://api.spotify.com/v1/tracks/6Qb7gtV6Q4MnUjSbkFcopl',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Qb7gtV6Q4MnUjSbkFcopl',
#   'duration_ms': 217347,
#   'time_signature': 4},
#  {'danceability': 0.27,
#   'energy': 0.944,
#   'key': 4,
#   'loudness': -4.199,
#   'mode': 1,
#   'speechiness': 0.0975,
#   'acousticness': 0.00501,
#   'instrumentalness': 2.05e-05,
#   'liveness': 0.116,
#   'valence': 0.606,
#   'tempo': 146.347,
#   'type': 'audio_features',
#   'id': '6hTcuIQa0sxrrByu9wTD7s',
#   'uri': 'spotify:track:6hTcuIQa0sxrrByu9wTD7s',
#   'track_href': 'https://api.spotify.com/v1/tracks/6hTcuIQa0sxrrByu9wTD7s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6hTcuIQa0sxrrByu9wTD7s',
#   'duration_ms': 269920,
#   'time_signature': 4},
#  {'danceability': 0.791,
#   'energy': 0.733,
#   'key': 5,
#   'loudness': -5.465,
#   'mode': 1,
#   'speechiness': 0.0633,
#   'acousticness': 0.523,
#   'instrumentalness': 0.0016,
#   'liveness': 0.167,
#   'valence': 0.962,
#   'tempo': 105.853,
#   'type': 'audio_features',
#   'id': '714hERk9U1W8FMYkoC83CO',
#   'uri': 'spotify:track:714hERk9U1W8FMYkoC83CO',
#   'track_href': 'https://api.spotify.com/v1/tracks/714hERk9U1W8FMYkoC83CO',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/714hERk9U1W8FMYkoC83CO',
#   'duration_ms': 244920,
#   'time_signature': 4},
#  {'danceability': 0.931,
#   'energy': 0.801,
#   'key': 4,
#   'loudness': -10.725,
#   'mode': 1,
#   'speechiness': 0.0548,
#   'acousticness': 0.496,
#   'instrumentalness': 0.379,
#   'liveness': 0.0563,
#   'valence': 0.971,
#   'tempo': 119.533,
#   'type': 'audio_features',
#   'id': '4qlfHfF422rd3I1FOs6N4s',
#   'uri': 'spotify:track:4qlfHfF422rd3I1FOs6N4s',
#   'track_href': 'https://api.spotify.com/v1/tracks/4qlfHfF422rd3I1FOs6N4s',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4qlfHfF422rd3I1FOs6N4s',
#   'duration_ms': 132040,
#   'time_signature': 4},
#  {'danceability': 0.435,
#   'energy': 0.423,
#   'key': 11,
#   'loudness': -8.795,
#   'mode': 1,
#   'speechiness': 0.024,
#   'acousticness': 0.0916,
#   'instrumentalness': 0.000659,
#   'liveness': 0.132,
#   'valence': 0.451,
#   'tempo': 91.137,
#   'type': 'audio_features',
#   'id': '2cWHN0WK52RGAWHgaDamUA',
#   'uri': 'spotify:track:2cWHN0WK52RGAWHgaDamUA',
#   'track_href': 'https://api.spotify.com/v1/tracks/2cWHN0WK52RGAWHgaDamUA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2cWHN0WK52RGAWHgaDamUA',
#   'duration_ms': 287091,
#   'time_signature': 3},
#  {'danceability': 0.653,
#   'energy': 0.73,
#   'key': 5,
#   'loudness': -10.613,
#   'mode': 1,
#   'speechiness': 0.0429,
#   'acousticness': 0.0115,
#   'instrumentalness': 1.02e-05,
#   'liveness': 0.0776,
#   'valence': 0.894,
#   'tempo': 108.709,
#   'type': 'audio_features',
#   'id': '4JfuiOWlWCkjP6OKurHjSn',
#   'uri': 'spotify:track:4JfuiOWlWCkjP6OKurHjSn',
#   'track_href': 'https://api.spotify.com/v1/tracks/4JfuiOWlWCkjP6OKurHjSn',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4JfuiOWlWCkjP6OKurHjSn',
#   'duration_ms': 220311,
#   'time_signature': 4},
#  {'danceability': 0.786,
#   'energy': 0.555,
#   'key': 10,
#   'loudness': -10.276,
#   'mode': 1,
#   'speechiness': 0.0471,
#   'acousticness': 0.454,
#   'instrumentalness': 0.0173,
#   'liveness': 0.0826,
#   'valence': 0.673,
#   'tempo': 95.1,
#   'type': 'audio_features',
#   'id': '1PehfITh0TTRx3LkDdV4h3',
#   'uri': 'spotify:track:1PehfITh0TTRx3LkDdV4h3',
#   'track_href': 'https://api.spotify.com/v1/tracks/1PehfITh0TTRx3LkDdV4h3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1PehfITh0TTRx3LkDdV4h3',
#   'duration_ms': 261373,
#   'time_signature': 4},
#  {'danceability': 0.543,
#   'energy': 0.422,
#   'key': 4,
#   'loudness': -12.243,
#   'mode': 1,
#   'speechiness': 0.383,
#   'acousticness': 0.592,
#   'instrumentalness': 0,
#   'liveness': 0.246,
#   'valence': 0.527,
#   'tempo': 107.146,
#   'type': 'audio_features',
#   'id': '0K9n8TBThz4xNAkF1eIlB6',
#   'uri': 'spotify:track:0K9n8TBThz4xNAkF1eIlB6',
#   'track_href': 'https://api.spotify.com/v1/tracks/0K9n8TBThz4xNAkF1eIlB6',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0K9n8TBThz4xNAkF1eIlB6',
#   'duration_ms': 204370,
#   'time_signature': 4},
#  {'danceability': 0.387,
#   'energy': 0.665,
#   'key': 1,
#   'loudness': -11.323,
#   'mode': 0,
#   'speechiness': 0.225,
#   'acousticness': 0.145,
#   'instrumentalness': 0.00167,
#   'liveness': 0.092,
#   'valence': 0.541,
#   'tempo': 174.896,
#   'type': 'audio_features',
#   'id': '4WFeJTXNHIS2wURtwlAkhu',
#   'uri': 'spotify:track:4WFeJTXNHIS2wURtwlAkhu',
#   'track_href': 'https://api.spotify.com/v1/tracks/4WFeJTXNHIS2wURtwlAkhu',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4WFeJTXNHIS2wURtwlAkhu',
#   'duration_ms': 199367,
#   'time_signature': 4},
#  {'danceability': 0.571,
#   'energy': 0.818,
#   'key': 0,
#   'loudness': -8.277,
#   'mode': 1,
#   'speechiness': 0.0337,
#   'acousticness': 0.00706,
#   'instrumentalness': 0.000181,
#   'liveness': 0.0877,
#   'valence': 0.773,
#   'tempo': 141.464,
#   'type': 'audio_features',
#   'id': '2dpO3NteNWUDL2S9e0t0Mi',
#   'uri': 'spotify:track:2dpO3NteNWUDL2S9e0t0Mi',
#   'track_href': 'https://api.spotify.com/v1/tracks/2dpO3NteNWUDL2S9e0t0Mi',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2dpO3NteNWUDL2S9e0t0Mi',
#   'duration_ms': 239213,
#   'time_signature': 4},
#  {'danceability': 0.592,
#   'energy': 0.398,
#   'key': 2,
#   'loudness': -10.81,
#   'mode': 0,
#   'speechiness': 0.0678,
#   'acousticness': 0.357,
#   'instrumentalness': 0.000925,
#   'liveness': 0.119,
#   'valence': 0.204,
#   'tempo': 150.038,
#   'type': 'audio_features',
#   'id': '1qjrYozGqc7upUgfN776lZ',
#   'uri': 'spotify:track:1qjrYozGqc7upUgfN776lZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/1qjrYozGqc7upUgfN776lZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1qjrYozGqc7upUgfN776lZ',
#   'duration_ms': 185293,
#   'time_signature': 3},
#  {'danceability': 0.449,
#   'energy': 0.54,
#   'key': 4,
#   'loudness': -14.637,
#   'mode': 0,
#   'speechiness': 0.0458,
#   'acousticness': 0.346,
#   'instrumentalness': 0.00944,
#   'liveness': 0.232,
#   'valence': 0.673,
#   'tempo': 120.107,
#   'type': 'audio_features',
#   'id': '5nfMtk9Zty1AITVo4YDhbb',
#   'uri': 'spotify:track:5nfMtk9Zty1AITVo4YDhbb',
#   'track_href': 'https://api.spotify.com/v1/tracks/5nfMtk9Zty1AITVo4YDhbb',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nfMtk9Zty1AITVo4YDhbb',
#   'duration_ms': 307440,
#   'time_signature': 4},
#  {'danceability': 0.472,
#   'energy': 0.373,
#   'key': 3,
#   'loudness': -12.98,
#   'mode': 1,
#   'speechiness': 0.0262,
#   'acousticness': 0.872,
#   'instrumentalness': 0.206,
#   'liveness': 0.147,
#   'valence': 0.459,
#   'tempo': 135.193,
#   'type': 'audio_features',
#   'id': '2JWKzkQbYsNzx019WyGzaH',
#   'uri': 'spotify:track:2JWKzkQbYsNzx019WyGzaH',
#   'track_href': 'https://api.spotify.com/v1/tracks/2JWKzkQbYsNzx019WyGzaH',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2JWKzkQbYsNzx019WyGzaH',
#   'duration_ms': 288267,
#   'time_signature': 4},
#  {'danceability': 0.379,
#   'energy': 0.76,
#   'key': 9,
#   'loudness': -10.961,
#   'mode': 1,
#   'speechiness': 0.0378,
#   'acousticness': 0.00298,
#   'instrumentalness': 0.0296,
#   'liveness': 0.104,
#   'valence': 0.491,
#   'tempo': 99.436,
#   'type': 'audio_features',
#   'id': '73TxYZd0lBCVRrHawrAglA',
#   'uri': 'spotify:track:73TxYZd0lBCVRrHawrAglA',
#   'track_href': 'https://api.spotify.com/v1/tracks/73TxYZd0lBCVRrHawrAglA',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/73TxYZd0lBCVRrHawrAglA',
#   'duration_ms': 274088,
#   'time_signature': 4},
#  {'danceability': 0.669,
#   'energy': 0.673,
#   'key': 7,
#   'loudness': -9.754,
#   'mode': 1,
#   'speechiness': 0.0248,
#   'acousticness': 0.203,
#   'instrumentalness': 0.0271,
#   'liveness': 0.164,
#   'valence': 0.867,
#   'tempo': 132.68,
#   'type': 'audio_features',
#   'id': '5lQKRR3MdJLtAwNBiT8Cq0',
#   'uri': 'spotify:track:5lQKRR3MdJLtAwNBiT8Cq0',
#   'track_href': 'https://api.spotify.com/v1/tracks/5lQKRR3MdJLtAwNBiT8Cq0',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5lQKRR3MdJLtAwNBiT8Cq0',
#   'duration_ms': 381999,
#   'time_signature': 4},
#  {'danceability': 0.838,
#   'energy': 0.757,
#   'key': 2,
#   'loudness': -5.399,
#   'mode': 1,
#   'speechiness': 0.0927,
#   'acousticness': 0.059,
#   'instrumentalness': 0.0119,
#   'liveness': 0.0271,
#   'valence': 0.602,
#   'tempo': 124.65,
#   'type': 'audio_features',
#   'id': '3wtMkvedoWMQ3XTKv7tqcZ',
#   'uri': 'spotify:track:3wtMkvedoWMQ3XTKv7tqcZ',
#   'track_href': 'https://api.spotify.com/v1/tracks/3wtMkvedoWMQ3XTKv7tqcZ',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3wtMkvedoWMQ3XTKv7tqcZ',
#   'duration_ms': 251333,
#   'time_signature': 4},
#  {'danceability': 0.614,
#   'energy': 0.763,
#   'key': 4,
#   'loudness': -8.949,
#   'mode': 0,
#   'speechiness': 0.133,
#   'acousticness': 0.171,
#   'instrumentalness': 0,
#   'liveness': 0.119,
#   'valence': 0.885,
#   'tempo': 84.236,
#   'type': 'audio_features',
#   'id': '7uPmQttafLiJyju14JREY4',
#   'uri': 'spotify:track:7uPmQttafLiJyju14JREY4',
#   'track_href': 'https://api.spotify.com/v1/tracks/7uPmQttafLiJyju14JREY4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7uPmQttafLiJyju14JREY4',
#   'duration_ms': 313707,
#   'time_signature': 4},
#  {'danceability': 0.5,
#   'energy': 0.185,
#   'key': 7,
#   'loudness': -20.242,
#   'mode': 1,
#   'speechiness': 0.0535,
#   'acousticness': 0.728,
#   'instrumentalness': 0.000746,
#   'liveness': 0.273,
#   'valence': 0.293,
#   'tempo': 121.002,
#   'type': 'audio_features',
#   'id': '7aE5WXu5sFeNRh3Z05wwu4',
#   'uri': 'spotify:track:7aE5WXu5sFeNRh3Z05wwu4',
#   'track_href': 'https://api.spotify.com/v1/tracks/7aE5WXu5sFeNRh3Z05wwu4',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7aE5WXu5sFeNRh3Z05wwu4',
#   'duration_ms': 304200,
#   'time_signature': 4},
#  {'danceability': 0.723,
#   'energy': 0.596,
#   'key': 9,
#   'loudness': -13.436,
#   'mode': 1,
#   'speechiness': 0.0308,
#   'acousticness': 0.0187,
#   'instrumentalness': 0.00513,
#   'liveness': 0.16,
#   'valence': 0.962,
#   'tempo': 128.068,
#   'type': 'audio_features',
#   'id': '6lrQo6KAYvb92MGk6ZuZlt',
#   'uri': 'spotify:track:6lrQo6KAYvb92MGk6ZuZlt',
#   'track_href': 'https://api.spotify.com/v1/tracks/6lrQo6KAYvb92MGk6ZuZlt',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6lrQo6KAYvb92MGk6ZuZlt',
#   'duration_ms': 249947,
#   'time_signature': 4},
#  {'danceability': 0.654,
#   'energy': 0.929,
#   'key': 1,
#   'loudness': -5.906,
#   'mode': 1,
#   'speechiness': 0.0998,
#   'acousticness': 0.0468,
#   'instrumentalness': 0,
#   'liveness': 0.0539,
#   'valence': 0.902,
#   'tempo': 144.774,
#   'type': 'audio_features',
#   'id': '6KTv0Z8BmVqM7DPxbGzpVC',
#   'uri': 'spotify:track:6KTv0Z8BmVqM7DPxbGzpVC',
#   'track_href': 'https://api.spotify.com/v1/tracks/6KTv0Z8BmVqM7DPxbGzpVC',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6KTv0Z8BmVqM7DPxbGzpVC',
#   'duration_ms': 168840,
#   'time_signature': 4},
#  {'danceability': 0.58,
#   'energy': 0.885,
#   'key': 0,
#   'loudness': -5.154,
#   'mode': 0,
#   'speechiness': 0.0715,
#   'acousticness': 0.1,
#   'instrumentalness': 0.00157,
#   'liveness': 0.146,
#   'valence': 0.788,
#   'tempo': 145.405,
#   'type': 'audio_features',
#   'id': '6zGDIDjfDkPyNxrEERO3XG',
#   'uri': 'spotify:track:6zGDIDjfDkPyNxrEERO3XG',
#   'track_href': 'https://api.spotify.com/v1/tracks/6zGDIDjfDkPyNxrEERO3XG',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6zGDIDjfDkPyNxrEERO3XG',
#   'duration_ms': 137933,
#   'time_signature': 4},
#  {'danceability': 0.476,
#   'energy': 0.604,
#   'key': 0,
#   'loudness': -10.85,
#   'mode': 0,
#   'speechiness': 0.117,
#   'acousticness': 0.11,
#   'instrumentalness': 4.15e-05,
#   'liveness': 0.134,
#   'valence': 0.583,
#   'tempo': 87.304,
#   'type': 'audio_features',
#   'id': '20VuO95A8RxUPlShnfYArW',
#   'uri': 'spotify:track:20VuO95A8RxUPlShnfYArW',
#   'track_href': 'https://api.spotify.com/v1/tracks/20VuO95A8RxUPlShnfYArW',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/20VuO95A8RxUPlShnfYArW',
#   'duration_ms': 395373,
#   'time_signature': 4},
#  {'danceability': 0.627,
#   'energy': 0.497,
#   'key': 7,
#   'loudness': -12.283,
#   'mode': 1,
#   'speechiness': 0.0271,
#   'acousticness': 0.387,
#   'instrumentalness': 0,
#   'liveness': 0.05,
#   'valence': 0.688,
#   'tempo': 129.531,
#   'type': 'audio_features',
#   'id': '7wC5vOh3fQibFYWjCIotKw',
#   'uri': 'spotify:track:7wC5vOh3fQibFYWjCIotKw',
#   'track_href': 'https://api.spotify.com/v1/tracks/7wC5vOh3fQibFYWjCIotKw',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7wC5vOh3fQibFYWjCIotKw',
#   'duration_ms': 170360,
#   'time_signature': 4},
#  {'danceability': 0.68,
#   'energy': 0.877,
#   'key': 5,
#   'loudness': -10.241,
#   'mode': 0,
#   'speechiness': 0.0353,
#   'acousticness': 0.191,
#   'instrumentalness': 0.000656,
#   'liveness': 0.349,
#   'valence': 0.922,
#   'tempo': 108.674,
#   'type': 'audio_features',
#   'id': '3PR79C1jVvLLLmgdyHkXl3',
#   'uri': 'spotify:track:3PR79C1jVvLLLmgdyHkXl3',
#   'track_href': 'https://api.spotify.com/v1/tracks/3PR79C1jVvLLLmgdyHkXl3',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3PR79C1jVvLLLmgdyHkXl3',
#   'duration_ms': 185107,
#   'time_signature': 4}]

# %%
tempo_value = 0
energy_value = 0
liveness_value = 0
loudness_value = 0
valence_value = 0

for x in features:
    tempo_value += x['tempo']/50
    energy_value += x['energy']/50
    liveness_value += x['liveness']/50
    loudness_value += x['loudness']/50
    valence_value += x['valence']/50

#tempo_value
print(str(tempo_value) + ", " + str(energy_value) + ", " + str(liveness_value) + ", " + str(loudness_value) + ", " + str(valence_value))
# Out:
# 121.61325999999998, 0.5934200000000003, 0.17713599999999996, -10.59172, 0.6485500000000002

# %%
exectime = time.time() + 10   # execute in 10 seconds
age = oscbuildparse.OSCMessage("/sound/age", None, [str(Age)])
tempo = oscbuildparse.OSCMessage("/sound/tempo", None, [tempo_value])
loudness = oscbuildparse.OSCMessage("/sound/loudness", None, [loudness_value])
#energy = oscbuildparse.OSCMessage("/sound/energy", None, [energy_value])
#liveness = oscbuildparse.OSCMessage("/sound/liveness", None, [liveness_value])
#valence = oscbuildparse.OSCMessage("/sound/freq", None, [valence_value])

bun = oscbuildparse.OSCBundle(oscbuildparse.unixtime2timetag(exectime), 
                              [age, tempo, loudness])
osc_send(bun, "processing")

#osc_terminate(

# %%
msg = osc_message_builder.OscMessageBuilder(address="/test")
msg.add_arg(Age)
msg.add_arg(tempo_value)
msg.add_arg(loudness_value)
#msg.add_arg(energy_value)
#msg.add_arg(liveness_value)
#msg.add_arg(valence_value)

msg = msg.build()
client.send(msg)

# %%
my_playlist = sp.user_playlist_create(user=username, name="Spotify Generative Art", public=True,
                                      description="Songs from the Title")

# %%
results = sp.user_playlist_add_tracks(username, my_playlist['id'], track_selection_list)
#print(results)

# %%
# sp.start_playback(deviceID, None, track_selection_list)
#Open the website by itself
webbrowser.open(my_playlist['external_urls']['spotify'])
# Out:
# True

# %%
#if((webbrowser.open(my_playlist['external_urls']['spotify'])) == True):
    #sp.start_playback(tracks[0]['uri'])
